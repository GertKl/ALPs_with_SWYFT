# %% [markdown]
# # Data dependence on g, spectral amplitude (flux) varied

# %%
import numpy as np
import random
import time

# %%
import sys
import os

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
import IPython

# %%
import pickle

# %%
import swyft

# %%
#%matplotlib inline
# %matplotlib ipympl

# %%
files_name = "simulate_g_values_index" + "_files"
parent_dir = (os.getcwd()+"/").split('/notebooks/', 1)[0]
start_dir = os.getcwd()
files_dir = os.getcwd() + "/" + files_name 
store_name = files_name.split("_files")[0] + "_store"
store_dir = os.getcwd() + "/" + files_name + "/" + store_name
sys.path.append(files_dir)

# %%
from ALP_quick_sim import ALP_sim

# %%
with open(files_dir+"/"+'config_objects.pickle', 'rb') as file:
    config_objects = pickle.load(file)
for key in config_objects.keys():
    locals()[key] = config_objects[key]

with open(files_dir+"/"+'sim_objects.pickle', 'rb') as file:
    sim_objects = pickle.load(file)
for key in sim_objects.keys():
    locals()[key] = sim_objects[key]

# with open(files_dir+"/"+'obs_objects.pickle', 'rb') as file:
#     obs_objects = pickle.load(file) 
# for key in obs_objects.keys():
#     locals()[key] = obs_objects[key]

# %%
stores={}
samples={}
for g in g_values:    
    store = swyft.ZarrStore(store_dir + "/" + store_name + "_" + str(g).replace('.','-'))
    stores[str(g).replace('.','-')] = store
    samples[g] = store
    print('#samples for g='+str(g)+": " + str(len(samples[g])))
# Out:
# #samples for g=0.2: 10
# #samples for g=0.4: 10
# #samples for g=0.8: 10

# %%
store_obs = swyft.ZarrStore(start_dir + "/simulate_g_values_none_obs_files/simulate_g_values_none_obs_store/simulate_g_values_none_obs_store_0-4")

# %%
os.path.exists(start_dir + "/simulate_g_values_none_obs_files/simulate_g_values_none_obs_store/simulate_g_values_none_obs_store_0-4")
# Out:
# True

# %%
len(store_obs)
# Out:
# 10

# %%
store['data'][0]
# Out:
# array([-0.00510935, -0.01652411, -0.01122943, -0.01780528, -0.01115268,
#        -0.00854781, -0.01252026, -0.01628072, -0.02127349, -0.02150163,
#        -0.01937471, -0.0207545 , -0.02000224, -0.02026775, -0.02726502,
#        -0.02109624, -0.03047883, -0.0320268 , -0.0272071 , -0.01140689,
#        -0.02433252, -0.02346075, -0.02605418, -0.02555728, -0.03024092,
#        -0.02640503, -0.03569082, -0.02605748, -0.03970643, -0.03077541,
#        -0.03246404, -0.02828323, -0.048921  , -0.03578717, -0.04279156,
#        -0.03663133, -0.04457116, -0.04403706, -0.04721208, -0.0633065 ,
#        -0.06120744, -0.07490786, -0.09398802, -0.08184841, -0.08608302,
#        -0.09237177, -0.09002389, -0.07885432, -0.10686202, -0.06166792,
#        -0.08304828, -0.0883123 , -0.09946466, -0.10283787, -0.08643124,
#        -0.1024853 , -0.098717  , -0.08783752, -0.11747621, -0.09049076,
#        -0.1065964 , -0.07983739, -0.09582512, -0.07913803, -0.10695965,
#        -0.12509194, -0.09029471, -0.09600176, -0.0976675 , -0.08756401,
#        -0.06104031, -0.06485464, -0.06518101, -0.06569318, -0.06488347,
#        -0.07421944, -0.12023236, -0.0714849 , -0.07255095, -0.08608081,
#        -0.08891782, -0.07328315, -0.12817393, -0.10264541, -0.10338126,
#        -0.11953591, -0.12203321, -0.05122541, -0.09603152, -0.06602454,
#        -0.05297553, -0.07374822, -0.09152518, -0.05608801, -0.06966279,
#        -0.08481422, -0.05955883, -0.01304922, -0.0577298 , -0.03379172,
#        -0.0563092 , -0.10000624, -0.08792627, -0.03803178, -0.05806074,
#        -0.04538626, -0.04771666,  0.01469089, -0.04119846, -0.03270525,
#        -0.03899262, -0.09490627, -0.07442665,  0.04870641, -0.06371795,
#        -0.04479844, -0.10731215, -0.11308283, -0.0207245 ,  0.02226603,
#        -0.04559397, -0.1059102 , -0.13341135, -0.05363016, -0.06077655,
#         0.03235055,  0.08100317,  0.07381922,  0.05567342,  0.0033042 ,
#        -0.18673217, -0.02387635,  0.05153261,  0.0430179 ,  0.00328994,
#        -0.01661549,  0.05253959,  0.01464438, -0.05435798,  0.02892137,
#        -0.17504705, -0.08653747, -0.1143056 ,  0.09053311,  0.02525291,
#         0.0238386 ,  0.02113805, -0.1297307 , -0.10478052, -0.0804551 ],
#       dtype=float32)

# %%
files_dir + "/simulate_g_values_none_obs_files/simulate_g_values_none_obs_store_0.4"
# Out:
# '/home/gert/ALPs_with_SWYFT/notebooks/padova_talk/simulate_g_values_none_files/simulate_g_values_none_obs_files/simulate_g_values_none_obs_store_0.4'

# %%
store_dir + "/" + store_name
# Out:
# '/home/gert/ALPs_with_SWYFT/notebooks/padova_talk/simulate_g_values_none_files/simulate_g_values_none_store/simulate_g_values_none_store'

# %% [markdown]
# # Compare signals to posterior width

# %%
widths =[
    [0.2,0.4,0.8],
]

colors_widths = [
    (1,0,0),
    (0,1,0),
    (0,0,1)
]

mean_ranges = [
    [0,0.5],
    [0.6,1.2],
    [1.5,3],
]

transparency = 0.5


len_fft = 2**11
b = 3
logx = 0
logy = 1

A.fontsize = 10

# xft = np.linspace(0,bt,int(bt*((max(xs)-min(xs))/len(xs))*len_ft))

lenx = int(b*((np.log10(A.emax)-np.log10(A.emin))/A.nbins)*len_fft)
xax_ft = np.linspace(0,b,lenx)

def corrfunction(counts):
    return abs(np.fft.fft(counts,n=len_fft))

# %%
A.generate_null()
# Out:
# Generating new null-hypothesis... done.

# %%
A._counts_null
# Out:
# {'y': array([3.87784817, 3.87829741, 3.87733947, 3.87640262, 3.87352262,
#         3.86840633, 3.86719059, 3.86637532, 3.86156782, 3.8540744 ,
#         3.84732523, 3.83970581, 3.83298241, 3.82942328, 3.82231039,
#         3.81271672, 3.8049228 , 3.79769535, 3.78785572, 3.77250742,
#         3.75187377, 3.73179665, 3.71286913, 3.69515306, 3.68190652,
#         3.66768079, 3.64709546, 3.62822603, 3.61118233, 3.5916381 ,
#         3.57154014, 3.55150927, 3.53421644, 3.51866075, 3.50112718,
#         3.48223553, 3.46237488, 3.4466423 , 3.43584605, 3.42143178,
#         3.40283978, 3.38623782, 3.36883834, 3.35322528, 3.34231955,
#         3.33142086, 3.31584988, 3.29607498, 3.28266365, 3.27118294,
#         3.25448217, 3.23783931, 3.22135264, 3.20766627, 3.1946579 ,
#         3.17948963, 3.1683851 , 3.15416345, 3.13534393, 3.12068555,
#         3.10529156, 3.08587535, 3.06849071, 3.05502916, 3.04397575,
#         3.0325033 , 3.01766508, 2.99691482, 2.9715691 , 2.94850063,
#         2.92077888, 2.88898048, 2.86727026, 2.85315366, 2.83278109,
#         2.81141208, 2.79417435, 2.78160226, 2.77841466, 2.78068601,
#         2.7791139 , 2.76524825, 2.74201576, 2.71964575, 2.69887748,
#         2.68063729, 2.66110931, 2.63781271, 2.61322742, 2.59106935,
#         2.57017143, 2.55086947, 2.53556998, 2.51093287, 2.48296256,
#         2.45956257, 2.43430718, 2.40924856, 2.39418953, 2.38597424,
#         2.37017642, 2.34055548, 2.31323555, 2.28600504, 2.25118534,
#         2.22722985, 2.21206951, 2.18670624, 2.15178817, 2.12261036,
#         2.10345061, 2.0771775 , 2.0429096 , 2.01575158, 1.9982164 ,
#         1.97929689, 1.9585705 , 1.93262677, 1.90721523, 1.88082396,
#         1.85177394, 1.83018608, 1.80550921, 1.77790603, 1.75097263,
#         1.72352431, 1.68984884, 1.65857454, 1.64329659, 1.61994509,
#         1.58467219, 1.55535527, 1.52825099, 1.50105014, 1.47383132,
#         1.44797925, 1.42458166, 1.40032897, 1.37657727, 1.35128987,
#         1.32117508, 1.29065745, 1.26043364, 1.23168618, 1.20519601,
#         1.18028138, 1.15495321, 1.1297307 , 1.10478052, 1.0804551 ])}

# %%
A.null_params
# Out:
# [0,
#  1.54e-09,
#  2.11,
#  560,
#  25.0,
#  39.0,
#  4.05,
#  500.0,
#  80.0,
#  280.0,
#  1.2,
#  0.58,
#  0.5,
#  0.18,
#  9.0,
#  -2.8]

# %%
def comparisons(which_truth,n=np.arange(0,20,1),n_truth=np.arange(0,20,1)):
    figs ={}
    A.configure_plot(xmin = None, xmax = None, ymin=-0.14, ymax=0.1, logx=1, logy=0) 

    A.configure_plot(legend=0)
    A.compute_case(new_fig=1,null=1,plot_obs=0,color="k",linestyle="--", label_exp=1,errorbands=0)
    A.configure_obs(nbins=50, nbins_etrue=50)
    A.configure_model(params=A.null_params)
    A.import_counts(obs=store_obs['data'][2],exp=store_obs['exp'][2])
    A.compute_case(new_fig=0,new_counts=0,plot_exp=0,color="k",linestyle="--", label_obs=0, label_exp=1)
    A.configure_obs(nbins=150, nbins_etrue=150)
    A.configure_plot(legend=1)
                
    for i, g in enumerate(widths[which_truth]):
        for ki, k in enumerate(n):
            A.configure_model(params=samples[g]['params'][k])
            A.import_counts(obs=samples[g]['data'][k],exp=samples[g]['exp'][k])
            A.compute_case(new_fig=0,new_counts=0,plot_obs=0,color=colors_widths[i],
                           label_exp=int(not ki), label_obs=int(not ki), errorbands=False,errors=0,
                           transparency = transparency)

# %%
comparisons(0, n=np.arange(0,3,1))
# Out:
# Generating new null-hypothesis... done.
# Generating new null-hypothesis... done.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
comparisons(0, n=np.arange(0,3,1))
# Out:
# Generating new null-hypothesis... done.
# Generating new null-hypothesis... done.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
